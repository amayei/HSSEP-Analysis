# %%
# Adjusting the xticks to make them horizontal instead of rotated

# Plotting
plt.figure(figsize=(10, 8))
bar_plot = sns.barplot(x='Advisor', y='Count', data=df, color='deepskyblue')

# Add labels to the bars
for index, row in df.iterrows():
    bar_plot.text(index, row['Count'] + 0.1, row['Count'], color='black', ha="center", fontsize=12)

# Set labels and title
plt.title('Submission by Advisors', fontsize=14)
plt.xlabel('Advisor', fontsize=12)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=0)  # Keep x labels horizontal
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data
data = {
    'Advisor': ['Aminata Saccoh', 'Foday Amara Francis', 'Halimatu Mama Kanneh', 'Tennyson Momoh', 'Vamunya Vamba Sesay'],
    'Count': [5, 2, 1, 5, 3]
}

# Create DataFrame
df = pd.DataFrame(data)

# Plotting
sns.set_palette("bright")  # Set a bright color palette
plt.figure(figsize=(10, 6))  # Adjust figure size for better spacing

# Use the 'hue' parameter to separate bars by color
bar_plot = sns.barplot(x='Advisor', y='Count', data=df, palette='Set2')  # You can change 'Set2' to any seaborn palette

# Add labels to the bars
for index, row in df.iterrows():
    bar_plot.text(index, row['Count'] + 0.1, row['Count'], color='black', ha="center", fontsize=12)

# Set labels and title
plt.title('Cumulative Submission per Advisor', fontsize=15)
plt.xlabel('Advisor', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=0)  # Set x labels horizontal
plt.tight_layout()

# Show plot
plt.show()
# Out:
# C:\Users\alhas\AppData\Local\Temp\ipykernel_1712\616220003.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(x='Advisor', y='Count', data=df, palette='Set2')  # You can change 'Set2' to any seaborn palette
